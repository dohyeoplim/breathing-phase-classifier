# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from src.dataset import BreathingAudioDataset

# %%
dataframe = pd.read_csv("../input/train.csv")

train_dataframe, validation_dataframe = train_test_split(
    dataframe, test_size=0.2, stratify=dataframe["Target"], random_state=42
)

train_dataset = BreathingAudioDataset(
    train_dataframe,
    "../input/train",
    is_training=True,
)

# %%
def extract_scalar_features(dataset):
    data = []
    labels = []
    for item in tqdm(dataset):
        x, label = item
        scalars = x['scalars'].numpy()
        data.append(scalars)
        labels.append(label.item())
    return pd.DataFrame(data), labels

# Assuming you have a loaded training dataset
df, labels = extract_scalar_features(train_dataset)
df.columns = [
    "log_mel_energy", "entropy_mel",
    "rms_mean", "rms_std", "rms_slope", "rms_tail_minus_head",
    "centroid_mean", "centroid_std", "centroid_tail_minus_head",
    "zcr_std", "zcr_tail_minus_head",
    "flatness_mean", "psd_low", "psd_mid", "psd_high"
]
df["target"] = ["E" if y > 0.5 else "I" for y in labels]

# Plot violin plots
plt.figure(figsize=(16, 10))
melted = df.melt(id_vars=["target"], var_name="feature", value_name="value")
sns.violinplot(data=melted, x="feature", y="value", hue="target", split=True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.title("Feature distributions by class")
plt.show()
# Out:
# 100%|██████████| 3200/3200 [00:11<00:00, 272.73it/s]

# %%
plt.figure(figsize=(12, 10))
corr = df.drop(columns="target").corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Feature Correlation Matrix")
plt.show()
print(corr)
# Out:
#                           log_mel_energy  entropy_mel  rms_mean   rms_std  \
# log_mel_energy                  1.000000     0.194897 -0.311972  0.366684
# entropy_mel                     0.194897     1.000000  0.054511 -0.092963
# rms_mean                       -0.311972     0.054511  1.000000 -0.951436
# rms_std                         0.366684    -0.092963 -0.951436  1.000000
# rms_slope                      -0.133418     0.011819  0.303619 -0.315491
# rms_tail_minus_head            -0.077487     0.012744  0.255420 -0.255448
# centroid_mean                  -0.167708     0.565541  0.096590 -0.142128
# centroid_std                    0.033587    -0.195941 -0.199659  0.229547
# centroid_tail_minus_head        0.000909    -0.016982 -0.123416  0.114981
# zcr_std                        -0.075363     0.283988 -0.059018  0.050962
# zcr_tail_minus_head            -0.000090     0.049695 -0.078640  0.080451
# flatness_mean                  -0.004730     0.079133 -0.028494  0.026477
# psd_low                         0.752594    -0.078334 -0.265914  0.340989
# psd_mid                        -0.005337     0.309874 -0.008836 -0.013675
# psd_high                       -0.039385     0.297985  0.031614 -0.060226
#
#                           rms_slope  rms_tail_minus_head  centroid_mean  \
# log_mel_energy            -0.133418            -0.077487      -0.167708
# entropy_mel                0.011819             0.012744       0.565541
# rms_mean                   0.303619             0.255420       0.096590
# rms_std                   -0.315491            -0.255448      -0.142128
# rms_slope                  1.000000             0.877798       0.059260
# rms_tail_minus_head        0.877798             1.000000       0.033978
# centroid_mean              0.059260             0.033978       1.000000
# centroid_std              -0.008891             0.023284       0.118906
# centroid_tail_minus_head  -0.347140            -0.388249       0.034520
# zcr_std                    0.011677             0.011016       0.639785
# zcr_tail_minus_head       -0.246673            -0.268241       0.063225
# flatness_mean              0.029071             0.033085       0.265954
# psd_low                   -0.120608            -0.065165      -0.497457
# psd_mid                   -0.014453            -0.038639       0.398091
# psd_high                   0.002079            -0.021526       0.462398
#
#                           centroid_std  centroid_tail_minus_head   zcr_std  \
# log_mel_energy                0.033587                  0.000909 -0.075363
# entropy_mel                  -0.195941                 -0.016982  0.283988
# rms_mean                     -0.199659                 -0.123416 -0.059018
# rms_std                       0.229547                  0.114981  0.050962
# rms_slope                    -0.008891                 -0.347140  0.011677
# rms_tail_minus_head           0.023284                 -0.388249  0.011016
# centroid_mean                 0.118906                  0.034520  0.639785
# centroid_std                  1.000000                  0.079360  0.221157
# centroid_tail_minus_head      0.079360                  1.000000  0.026270
# zcr_std                       0.221157                  0.026270  1.000000
# zcr_tail_minus_head           0.023916                  0.559066  0.058137
# flatness_mean                 0.711793                  0.053401  0.052184
# psd_low                       0.035307                  0.020982 -0.292743
# psd_mid                      -0.089099                 -0.031002  0.198778
# psd_high                     -0.040583                 -0.031306  0.263747
#
#                           zcr_tail_minus_head  flatness_mean   psd_low  \
# log_mel_energy                      -0.000090      -0.004730  0.752594
# entropy_mel                          0.049695       0.079133 -0.078334
# rms_mean                            -0.078640      -0.028494 -0.265914
# rms_std                              0.080451       0.026477  0.340989
# rms_slope                           -0.246673       0.029071 -0.120608
# rms_tail_minus_head                 -0.268241       0.033085 -0.065165
# centroid_mean                        0.063225       0.265954 -0.497457
# centroid_std                         0.023916       0.711793  0.035307
# centroid_tail_minus_head             0.559066       0.053401  0.020982
# zcr_std                              0.058137       0.052184 -0.292743
# zcr_tail_minus_head                  1.000000      -0.016419 -0.016819
# flatness_mean                       -0.016419       1.000000 -0.073190
# psd_low                             -0.016819      -0.073190  1.000000
# psd_mid                             -0.001407       0.056141 -0.477789
# psd_high                             0.003593       0.081787 -0.504483
#
#                            psd_mid  psd_high
# log_mel_energy           -0.005337 -0.039385
# entropy_mel               0.309874  0.297985
# rms_mean                 -0.008836  0.031614
# rms_std                  -0.013675 -0.060226
# rms_slope                -0.014453  0.002079
# rms_tail_minus_head      -0.038639 -0.021526
# centroid_mean             0.398091  0.462398
# centroid_std             -0.089099 -0.040583
# centroid_tail_minus_head -0.031002 -0.031306
# zcr_std                   0.198778  0.263747
# zcr_tail_minus_head      -0.001407  0.003593
# flatness_mean             0.056141  0.081787
# psd_low                  -0.477789 -0.504483
# psd_mid                   1.000000  0.687940
# psd_high                  0.687940  1.000000

# %%
for col in df.columns[:-1]:
    auc = roc_auc_score([1 if t == "E" else 0 for t in df["target"]], df[col])
    print(f"{col:<25}: {auc:.4f}")
# Out:
# log_mel_energy           : 0.4259
# entropy_mel              : 0.3868
# rms_mean                 : 0.4957
# rms_std                  : 0.4993
# rms_slope                : 0.5269
# rms_tail_minus_head      : 0.4757
# centroid_mean            : 0.5039
# centroid_std             : 0.5162
# centroid_tail_minus_head : 0.4599
# zcr_std                  : 0.5336
# zcr_tail_minus_head      : 0.4624
# flatness_mean            : 0.4894
# psd_low                  : 0.4400
# psd_mid                  : 0.4702
# psd_high                 : 0.4910

# %%
grouped_stats = df.groupby("target").describe().T
pd.set_option("display.max_rows", None)
print("\n📊 Descriptive Statistics by Class (E vs I):\n")
print(grouped_stats.round(4))
# Out:
# 📊 Descriptive Statistics by Class (E vs I):
#
# target                                  E          I
# log_mel_energy           count  1600.0000  1600.0000
#                          mean      8.5083     8.5238
#                          std       0.0740     0.0680
#                          min       8.1400     7.6371
#                          25%       8.4828     8.5092
#                          50%       8.5367     8.5501
#                          75%       8.5609     8.5648
#                          max       8.5747     8.5746
# entropy_mel              count  1600.0000  1600.0000
#                          mean     -0.2121    -0.1833
#                          std       0.0738     0.0612
#                          min      -0.5278    -0.5883
#                          25%      -0.2557    -0.2213
#                          50%      -0.2025    -0.1743
#                          75%      -0.1567    -0.1377
#                          max      -0.0464    -0.0486
# rms_mean                 count  1600.0000  1600.0000
#                          mean      0.0876     0.0879
#                          std       0.0075     0.0069
#                          min       0.0490     0.0524
#                          25%       0.0838     0.0842
#                          50%       0.0894     0.0895
#                          75%       0.0932     0.0930
#                          max       0.0977     0.0977
# rms_std                  count  1600.0000  1600.0000
#                          mean      0.0406     0.0406
#                          std       0.0143     0.0137
#                          min       0.0084     0.0075
#                          25%       0.0304     0.0307
#                          50%       0.0399     0.0398
#                          75%       0.0507     0.0500
#                          max       0.0858     0.0838
# rms_slope                count  1600.0000  1600.0000
#                          mean     -0.0008    -0.0009
#                          std       0.0018     0.0017
#                          min      -0.0070    -0.0064
#                          25%      -0.0017    -0.0020
#                          50%      -0.0006    -0.0007
#                          75%       0.0003     0.0001
#                          max       0.0051     0.0046
# rms_tail_minus_head      count  1600.0000  1600.0000
#                          mean     -0.0184    -0.0139
#                          std       0.0476     0.0436
#                          min      -0.1742    -0.1563
#                          25%      -0.0468    -0.0374
#                          50%      -0.0107    -0.0080
#                          75%       0.0088     0.0089
#                          max       0.1604     0.1340
# centroid_mean            count  1600.0000  1600.0000
#                          mean    465.7414   464.2111
#                          std     117.4136   109.0224
#                          min     208.0611   181.6584
#                          25%     382.3854   393.1544
#                          50%     453.2357   448.9611
#                          75%     534.9068   517.8647
#                          max     968.1793  1103.8997
# centroid_std             count  1600.0000  1600.0000
#                          mean    132.1282   128.7596
#                          std      51.7870    50.0895
#                          min      33.7540    30.8559
#                          25%      95.8488    92.0872
#                          50%     124.7378   122.0549
#                          75%     159.3340   157.0004
#                          max     513.0075   397.0000
# centroid_tail_minus_head count  1600.0000  1600.0000
#                          mean     31.4854    49.3072
#                          std     132.0344   125.7963
#                          min    -531.2265  -521.5468
#                          25%     -49.3449   -27.6943
#                          50%      30.0150    46.4301
#                          75%     112.9466   125.7047
#                          max     561.9789   596.8495
# zcr_std                  count  1600.0000  1600.0000
#                          mean      0.0111     0.0105
#                          std       0.0066     0.0063
#                          min       0.0011     0.0017
#                          25%       0.0068     0.0063
#                          50%       0.0095     0.0086
#                          75%       0.0138     0.0128
#                          max       0.0464     0.0560
# zcr_tail_minus_head      count  1600.0000  1600.0000
#                          mean     -0.0000     0.0014
#                          std       0.0125     0.0119
#                          min      -0.0709    -0.0742
#                          25%      -0.0055    -0.0032
#                          50%       0.0000     0.0006
#                          75%       0.0052     0.0055
#                          max       0.0846     0.0874
# flatness_mean            count  1600.0000  1600.0000
#                          mean      0.0004     0.0004
#                          std       0.0005     0.0005
#                          min       0.0000     0.0000
#                          25%       0.0001     0.0001
#                          50%       0.0002     0.0003
#                          75%       0.0005     0.0005
#                          max       0.0069     0.0067
# psd_low                  count  1600.0000  1600.0000
#                          mean      0.0086     0.0088
#                          std       0.0014     0.0013
#                          min       0.0014     0.0008
#                          25%       0.0078     0.0082
#                          50%       0.0089     0.0092
#                          75%       0.0097     0.0098
#                          max       0.0118     0.0123
# psd_mid                  count  1600.0000  1600.0000
#                          mean      0.0002     0.0002
#                          std       0.0003     0.0003
#                          min       0.0000     0.0000
#                          25%       0.0000     0.0000
#                          50%       0.0001     0.0001
#                          75%       0.0001     0.0002
#                          max       0.0054     0.0034
# psd_high                 count  1600.0000  1600.0000
#                          mean      0.0001     0.0001
#                          std       0.0002     0.0002
#                          min       0.0000     0.0000
#                          25%       0.0000     0.0000
#                          50%       0.0000     0.0000
#                          75%       0.0001     0.0001
#                          max       0.0019     0.0019
